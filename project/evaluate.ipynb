# %%
gold_test_path = "dev_aspects.txt"
pred_test_path = 'dev_pred_aspects_last.txt'

# %% [markdown]
# # Оценка 1: accuracy по выделению упоминаний с категориями

# %%
from collections import defaultdict

# %%
gold_aspect_cats = {}
with open(gold_test_path, encoding='utf8') as fg:
    for line in fg:
        line = line.rstrip('\r\n').split('\t')
        if line[0] not in gold_aspect_cats:
            gold_aspect_cats[line[0]] = {"starts":[], "ends":[], "cats":[], "sents":[]}
        gold_aspect_cats[line[0]]["starts"].append(int(line[3]))
        gold_aspect_cats[line[0]]["ends"].append(int(line[4]))
        gold_aspect_cats[line[0]]["cats"].append(line[1])
        gold_aspect_cats[line[0]]["sents"].append(line[5])

# %%
full_match, partial_match, full_cat_match, partial_cat_match = 0, 0, 0, 0
total = 0
fully_matched_pairs = []
partially_matched_pairs = []
with open(pred_test_path, encoding='utf8') as fp:
    for line in fp:
        total += 1
        line = line.rstrip('\r\n').split('\t')
        print(line)
        start, end = int(line[3]), int(line[4])
        category = line[1]
        doc_gold_aspect_cats = gold_aspect_cats[line[0]]
        if start in doc_gold_aspect_cats["starts"]:
            i = doc_gold_aspect_cats["starts"].index(start)
            if doc_gold_aspect_cats["ends"][i] == end:
                full_match += 1
                if doc_gold_aspect_cats["cats"][i] == category:
                    full_cat_match += 1
                else:
                    partial_cat_match += 1
                fully_matched_pairs.append(
                    (
                        [
                            doc_gold_aspect_cats["starts"][i], 
                            doc_gold_aspect_cats["ends"][i], 
                            doc_gold_aspect_cats["cats"][i],
                            doc_gold_aspect_cats["sents"][i]
                        ],
                        line
                    )
                )
                continue
        for s_pos in doc_gold_aspect_cats["starts"]:
            if start <= s_pos:
                i = doc_gold_aspect_cats["starts"].index(s_pos)
                if doc_gold_aspect_cats["ends"][i] == end:
                    partial_match += 1
                    partially_matched_pairs.append(
                        (
                            [
                                doc_gold_aspect_cats["starts"][i], 
                                doc_gold_aspect_cats["ends"][i], 
                                doc_gold_aspect_cats["cats"][i],
                                doc_gold_aspect_cats["sents"][i]
                            ],
                            line
                        )
                    )
                    if doc_gold_aspect_cats["cats"][i] == category:
                        partial_cat_match += 1
                    continue
                matched = False
                for e_pos in doc_gold_aspect_cats["ends"][i:]:
                    if s_pos <= end <= e_pos:
                        partial_match += 1
                        partially_matched_pairs.append(
                            (
                                [
                                    doc_gold_aspect_cats["starts"][i], 
                                    doc_gold_aspect_cats["ends"][i], 
                                    doc_gold_aspect_cats["cats"][i],
                                    doc_gold_aspect_cats["sents"][i]
                                ],
                                line
                            )
                        )
                        if doc_gold_aspect_cats["cats"][i] == category:
                            partial_cat_match += 1
                        matched = True
                        break
                if matched:
                    break
            if start > s_pos:
                i = doc_gold_aspect_cats["starts"].index(s_pos)
                if start < doc_gold_aspect_cats["ends"][i] <= end:
                    partial_match += 1
                    partially_matched_pairs.append(
                        (
                            [
                                doc_gold_aspect_cats["starts"][i], 
                                doc_gold_aspect_cats["ends"][i], 
                                doc_gold_aspect_cats["cats"][i],
                                doc_gold_aspect_cats["sents"][i]
                            ],
                            line
                        )
                    )
                    if doc_gold_aspect_cats["cats"][i] == category:
                        partial_cat_match += 1
                    break
# Out:
# ['13823', 'Service', 'встретил', '138', '146', 'neutral']
# ['13823', 'Service', 'девушка', '179', '186', 'neutral']
# ['13823', 'Food', 'меню', '639', '643', 'neutral']
# ['13823', 'Service', 'официантка', '242', '252', 'neutral']
# ['13823', 'Whole', 'ресторан', '337', '345', 'neutral']
# ['13823', 'Service', 'заведения', '431', '440', 'neutral']
# ['13823', 'Price', 'цене', '582', '586', 'neutral']
# ['13823', 'Whole', 'место', '610', '615', 'positive']
# ['13823', 'Food', 'меню', '639', '643', 'positive']
# ['13823', 'Price', 'цены', '656', '660', 'positive']
# ['13823', 'Service', 'обслуживания', '680', '692', 'positive']
# ['13823', 'Whole', 'заведению', '735', '744', 'positive']
# ['1427', 'Whole', 'заведение', '27', '36', 'neutral']
# ['1427', 'Food', 'ужинали', '113', '120', 'neutral']
# ['1427', 'Service', 'обслуживанием', '169', '182', 'neutral']
# ['1427', 'Whole', 'посещение', '205', '214', 'neutral']
# ['1427', 'Whole', 'заведения', '222', '231', 'neutral']
# ['1427', 'Interior', 'залы', '333', '337', 'neutral']
# ['1427', 'Interior', 'веранде', '350', '357', 'neutral']
# ['1427', 'Service', 'встретил', '394', '402', 'neutral']
# ['1427', 'Service', 'предложил', '423', '432', 'neutral']
# ['1427', 'Service', 'Проводила', '475', '484', 'neutral']
# ['1427', 'Service', 'администратор', '566', '579', 'neutral']
# ['1427', 'Service', 'налили', '630', '636', 'neutral']
# ['1427', 'Price', 'бесплатной', '647', '657', 'neutral']
# ['1427', 'Food', 'воды', '658', '662', 'neutral']
# ['1427', 'Service', 'Обслуживание', '784', '796', 'neutral']
# ['1427', 'Service', 'администратор', '566', '579', 'neutral']
# ['1427', 'Service', 'помогает', '927', '935', 'neutral']
# ['1427', 'Service', 'официантам', '1022', '1032', 'neutral']
# ['1427', 'Whole', 'вечер', '1139', '1144', 'neutral']
# ['1427', 'Service', 'девушке', '1177', '1184', 'neutral']
# ['1427', 'Interior', 'атмосферу', '1197', '1206', 'neutral']
# ['1427', 'Service', 'сотрудников', '1234', '1245', 'neutral']
# ['16714', 'Food', 'кухню', '118', '123', 'neutral']
# ['16714', 'Food', 'овощи', '214', '219', 'neutral']
# ['16714', 'Food', 'Хачипури', '230', '238', 'neutral']
# ['16714', 'Food', 'сыра', '282', '286', 'neutral']
# ['16714', 'Food', 'Салат', '315', '320', 'positive']
# ['16714', 'Food', 'баранина', '339', '347', 'positive']
# ['16714', 'Food', 'овощи', '214', '219', 'positive']
# ['16714', 'Service', 'Сервис', '373', '379', 'positive']
# ['16714', 'Service', 'Официант', '412', '420', 'negative']
# ['16714', 'Interior', 'Интерьер', '472', '480', 'negative']
# ['16714', 'Food', 'обеда', '559', '564', 'negative']
# ['16714', 'Service', 'администратору', '658', '672', 'negative']
# ['16714', 'Service', 'девушки', '725', '732', 'negative']
# ['16714', 'Service', 'сервис', '782', '788', 'positive']
# ['797', 'Whole', 'ресторане', '7', '16', 'neutral']
# ['797', 'Food', 'выпить', '89', '95', 'neutral']
# ['797', 'Food', 'чаю', '96', '99', 'neutral']
# ['797', 'Food', 'вина', '102', '106', 'neutral']
# ['797', 'Service', 'официантка', '143', '153', 'neutral']
# ['797', 'Whole', 'ресторане', '7', '16', 'neutral']
# ['797', 'Service', 'официантка', '143', '153', 'neutral']
# ['797', 'Service', 'поработают', '550', '560', 'neutral']
# ['797', 'Service', 'Чаевые', '645', '651', 'negative']
# ['34710', 'Service', 'обслуживание', '30', '42', 'neutral']
# ['34710', 'Service', 'обслужили', '86', '95', 'neutral']
# ['34710', 'Service', 'дали', '362', '366', 'neutral']
# ['34710', 'Service', 'меню', '387', '391', 'neutral']
# ['34710', 'Service', 'несли', '129', '134', 'neutral']
# ['34710', 'Food', 'напитки', '135', '142', 'neutral']
# ['34710', 'Service', 'салат', '162', '167', 'neutral']
# ['34710', 'Price', 'счет', '174', '178', 'neutral']
# ['34710', 'Service', 'официантов', '244', '254', 'neutral']
# ['34710', 'Service', 'официантка', '285', '295', 'neutral']
# ['34710', 'Service', 'дали', '362', '366', 'neutral']
# ['34710', 'Service', 'меню', '387', '391', 'neutral']
# ['34710', 'Service', 'меню', '387', '391', 'neutral']
# ['34710', 'Service', 'официантка', '285', '295', 'neutral']
# ['34710', 'Food', 'супа', '573', '577', 'neutral']
# ['34710', 'Service', 'принесла', '578', '586', 'neutral']
# ['34710', 'Food', 'Напитки', '618', '625', 'neutral']
# ['34710', 'Service', 'принесла', '578', '586', 'neutral']
# ['34710', 'Food', 'десерта', '648', '655', 'neutral']
# ['34710', 'Food', 'напитки', '135', '142', 'neutral']
# ['34710', 'Food', 'кухня', '718', '723', 'positive']
# ['34710', 'Service', 'официантов', '244', '254', 'neutral']
# ['34710', 'Whole', 'впечатление', '809', '820', 'positive']
# ['33798', 'Whole', 'ресторана', '23', '32', 'negative']
# ['33798', 'Food', 'поесть', '114', '120', 'neutral']
# ['33798', 'Food', 'меню', '167', '171', 'neutral']
# ['33798', 'Food', 'Паста', '278', '283', 'positive']
# ['33798', 'Food', 'суши', '286', '290', 'positive']
# ['33798', 'Food', 'еде', '352', '355', 'negative']
# ['33798', 'Interior', 'интерьер', '378', '386', 'positive']
# ['33798', 'Service', 'Официанты', '409', '418', 'neutral']
# ['33798', 'Whole', 'ресторан', '479', '487', 'positive']
# ['2073', 'Whole', 'ресторане', '31', '40', 'neutral']
# ['2073', 'Whole', 'заведению', '97', '106', 'neutral']
# ['2073', 'Whole', 'вечер', '116', '121', 'neutral']
# ['2073', 'Whole', 'месте', '203', '208', 'neutral']
# ['2073', 'Interior', 'интерьер', '223', '231', 'negative']
# ['2073', 'Food', 'кухня', '242', '247', 'negative']
# ['2073', 'Service', 'обслуживания', '314', '326', 'neutral']
# ['2073', 'Whole', 'ресторан', '1179', '1187', 'neutral']
# ['2073', 'Service', 'официантка', '377', '387', 'neutral']
# ['2073', 'Food', 'вино', '537', '541', 'neutral']
# ['2073', 'Food', 'оливки', '769', '775', 'neutral']
# ['2073', 'Whole', 'ресторан', '1179', '1187', 'neutral']
# ['785', 'Whole', 'Ресторан', '69', '77', 'positive']
# ['785', 'Interior', 'интерьер', '90', '98', 'positive']
# ['785', 'Interior', 'места', '115', '120', 'positive']
# ['785', 'Interior', 'украсили', '122', '130', 'positive']
# ['785', 'Interior', 'красиво', '131', '138', 'positive']
# ['785', 'Food', 'меню', '153', '157', 'both']
# ['785', 'Food', 'Меню', '176', '180', 'neutral']
# ['785', 'Food', 'блюд', '339', '343', 'neutral']
# ['785', 'Food', 'торта', '358', '363', 'positive']
# ['785', 'Service', 'помогла', '392', '399', 'positive']
# ['785', 'Service', 'администратор', '416', '429', 'positive']
# ['785', 'Service', 'помогла', '392', '399', 'neutral']
# ['1434', 'Whole', 'ресторан', '72', '80', 'neutral']
# ['1434', 'Interior', 'интерьер', '140', '148', 'negative']
# ['1434', 'Whole', 'место', '223', '228', 'positive']
# ['1434', 'Service', 'официанту', '276', '285', 'neutral']
# ['1434', 'Food', 'блюда', '602', '607', 'positive']
# ['1434', 'Food', 'десерт', '672', '678', 'neutral']
# ['1434', 'Food', 'десерт', '672', '678', 'neutral']
# ['1434', 'Whole', 'заведение', '809', '818', 'positive']
# ['22386', 'Price', 'Ценник', '86', '92', 'neutral']
# ['22386', 'Food', 'соленья', '163', '170', 'neutral']
# ['22386', 'Food', 'угря', '269', '273', 'neutral']
# ['22386', 'Service', 'официантки', '348', '358', 'neutral']
# ['22386', 'Service', 'официантка', '589', '599', 'neutral']
# ['32442', 'Interior', 'зале', '159', '163', 'neutral']
# ['32442', 'Service', 'Администраторы', '248', '262', 'positive']
# ['32442', 'Service', 'ведущих', '304', '311', 'positive']
# ['32442', 'Food', 'Меню', '347', '351', 'neutral']
# ['32442', 'Food', 'алкоголь', '369', '377', 'neutral']
# ['15423', 'Whole', 'заведение', '7', '16', 'positive']
# ['15423', 'Service', 'персонала', '129', '138', 'positive']
# ['15423', 'Interior', 'песни', '248', '253', 'positive']
# ['15423', 'Food', 'кухни', '309', '314', 'positive']
# ['15423', 'Food', 'готовят', '319', '326', 'positive']
# ['15423', 'Service', 'обслуживание', '543', '555', 'positive']
# ['15423', 'Service', 'обслуживание', '543', '555', 'positive']
# ['15423', 'Service', 'девушка', '707', '714', 'positive']
# ['7193', 'Whole', 'место', '19', '24', 'positive']
# ['7193', 'Food', 'перекусить', '78', '88', 'positive']
# ['7193', 'Service', 'Официанты', '169', '178', 'neutral']
# ['7193', 'Service', 'Официанты', '169', '178', 'positive']
# ['7193', 'Service', 'работают', '266', '274', 'positive']
# ['7193', 'Food', 'Еды', '321', '324', 'positive']
# ['7193', 'Whole', 'место', '19', '24', 'positive']
# ['7193', 'Food', 'пообедать', '422', '431', 'positive']
# ['13100', 'Service', 'встретила', '202', '211', 'positive']
# ['13100', 'Service', 'Обслуживал', '242', '252', 'positive']
# ['13100', 'Food', 'закуски', '515', '522', 'positive']
# ['13100', 'Food', 'салаты', '525', '531', 'positive']
# ['13100', 'Food', 'десерт', '564', '570', 'positive']
# ['13100', 'Food', 'Наполеон', '595', '603', 'positive']
# ['13100', 'Food', 'повара', '809', '815', 'positive']
# ['13100', 'Food', 'кухню', '928', '933', 'positive']
# ['13100', 'Service', 'обслуживание', '953', '965', 'positive']
# ['13100', 'Interior', 'Интерьер', '966', '974', 'positive']
# ['13100', 'Interior', 'туалет', '999', '1005', 'positive']
# ['13100', 'Food', 'еды', '1091', '1094', 'positive']
# ['35635', 'Whole', 'ресторан', '99', '107', 'neutral']
# ['35635', 'Food', 'кухня', '150', '155', 'positive']
# ['35635', 'Service', 'обслуживание', '159', '171', 'positive']
# ['35635', 'Interior', 'атмосфера', '173', '182', 'positive']
# ['35635', 'Interior', 'настроение', '185', '195', 'positive']
# ['35635', 'Service', 'руководителей', '631', '644', 'neutral']
# ['35635', 'Whole', 'ресторан', '99', '107', 'neutral']
# ['35635', 'Service', 'официант', '773', '781', 'positive']
# ['35635', 'Food', 'поели', '901', '906', 'neutral']
# ['35635', 'Food', 'пирожков', '959', '967', 'positive']
# ['35635', 'Interior', 'настроение', '185', '195', 'positive']
# ['35635', 'Service', 'официант', '773', '781', 'neutral']
# ['35635', 'Whole', 'рестораном', '1206', '1216', 'negative']
# ['35635', 'Whole', 'ресторан', '99', '107', 'negative']
# ['2107', 'Whole', 'заведение', '21', '30', 'negative']
# ['2107', 'Service', 'официанта', '170', '179', 'neutral']
# ['2107', 'Service', 'пледы', '203', '208', 'neutral']
# ['2107', 'Food', 'Чай', '210', '213', 'neutral']
# ['2107', 'Service', 'принесли', '276', '284', 'neutral']
# ['2107', 'Service', 'заказа', '491', '497', 'neutral']
# ['2107', 'Service', 'принесли', '276', '284', 'neutral']
# ['2107', 'Food', 'салат', '287', '292', 'neutral']
# ['2107', 'Service', 'принесли', '276', '284', 'neutral']
# ['2107', 'Food', 'горячее', '325', '332', 'neutral']
# ['2107', 'Food', 'блюдо', '446', '451', 'neutral']
# ['2107', 'Service', 'заказа', '491', '497', 'neutral']
# ['2107', 'Food', 'Порции', '610', '616', 'neutral']
# ['36085', 'Whole', 'заведении', '88', '97', 'neutral']
# ['36085', 'Whole', 'кафе', '187', '191', 'positive']
# ['36085', 'Interior', 'интерьер', '209', '217', 'positive']
# ['36085', 'Food', 'блюда', '237', '242', 'positive']
# ['36085', 'Service', 'персонал', '310', '318', 'positive']
# ['36085', 'Whole', 'место', '455', '460', 'positive']
# ['7824', 'Whole', 'ресторане', '19', '28', 'positive']
# ['7824', 'Whole', 'месте', '96', '101', 'positive']
# ['7824', 'Food', 'кухней', '112', '118', 'positive']
# ['7824', 'Whole', 'заведении', '310', '319', 'positive']
# ['7824', 'Food', 'салатов', '374', '381', 'negative']
# ['7824', 'Food', 'соус', '425', '429', 'negative']
# ['7824', 'Food', 'курица', '441', '447', 'negative']
# ['7824', 'Food', 'горячего', '519', '527', 'negative']
# ['7824', 'Food', 'манты', '532', '537', 'negative']
# ['7824', 'Food', 'десерты', '646', '653', 'positive']
# ['7824', 'Food', 'Пирожные', '655', '663', 'positive']
# ['7824', 'Whole', 'ресторана', '719', '728', 'positive']
# ['34045', 'Whole', 'кафе', '34', '38', 'neutral']
# ['34045', 'Food', 'Кухня', '98', '103', 'positive']
# ['34045', 'Service', 'Обслуживание', '197', '209', 'positive']
# ['34045', 'Service', 'персонал', '229', '237', 'positive']
# ['34045', 'Whole', 'кафе', '34', '38', 'neutral']
# ['34045', 'Food', 'кофе', '347', '351', 'neutral']
# ['34045', 'Interior', 'обстановке', '364', '374', 'neutral']
# ['11421', 'Whole', 'ресторане', '12', '21', 'positive']
# ['11421', 'Food', 'Ужинали', '72', '79', 'neutral']
# ['11421', 'Service', 'обслуживание', '111', '123', 'positive']
# ['11421', 'Food', 'кухне', '290', '295', 'negative']
# ['11421', 'Food', 'ужина', '340', '345', 'neutral']
# ['11421', 'Interior', 'музыканты', '353', '362', 'neutral']
# ['11421', 'Interior', 'музыка', '385', '391', 'positive']
# ['11421', 'Whole', 'ресторан', '427', '435', 'positive']
# ['36126', 'Whole', 'посещения', '222', '231', 'neutral']
# ['36126', 'Whole', 'места', '238', '243', 'neutral']
# ['36126', 'Food', 'кухня', '410', '415', 'neutral']
# ['36126', 'Service', 'сотрудники', '465', '475', 'negative']
# ['36126', 'Service', 'администратор', '478', '491', 'negative']
# ['36126', 'Service', 'помогла', '501', '508', 'negative']
# ['36126', 'Service', 'официант', '544', '552', 'negative']
# ['36126', 'Service', 'работа', '560', '566', 'negative']
# ['36126', 'Service', 'приносила', '620', '629', 'negative']
# ['36126', 'Service', 'уносила', '632', '639', 'negative']
# ['36126', 'Service', 'спрашивала', '648', '658', 'negative']
# ['36126', 'Service', 'советовала', '675', '685', 'negative']
# ['36126', 'Whole', 'ресторанах', '723', '733', 'neutral']
# ['36126', 'Service', 'обслуживание', '738', '750', 'neutral']
# ['36126', 'Whole', 'коллективу', '786', '796', 'positive']
# ['36126', 'Whole', 'ресторан', '848', '856', 'neutral']
# ['13186', 'Service', 'девушка', '72', '79', 'neutral']
# ['13186', 'Food', 'вина', '125', '129', 'neutral']
# ['13186', 'Food', 'вином', '168', '173', 'neutral']
# ['13186', 'Service', 'официанты', '218', '227', 'neutral']
# ['13186', 'Food', 'вино', '248', '252', 'neutral']
# ['13186', 'Food', 'вина', '125', '129', 'neutral']
# ['13186', 'Food', 'салат', '330', '335', 'neutral']
# ['13186', 'Food', 'салат', '330', '335', 'neutral']
# ['13186', 'Food', 'салат', '330', '335', 'neutral']
# ['13186', 'Interior', 'атмосфера', '629', '638', 'positive']
# ['9721', 'Whole', 'ресторане', '29', '38', 'neutral']
# ['9721', 'Whole', 'ресторан', '261', '269', 'positive']
# ['9721', 'Interior', 'интерьер', '146', '154', 'positive']
# ['9721', 'Whole', 'ресторанах', '175', '185', 'positive']
# ['9721', 'Whole', 'ресторан', '261', '269', 'neutral']
# ['9721', 'Service', 'персонал', '295', '303', 'neutral']
# ['9721', 'Service', 'Официанты', '305', '314', 'neutral']
# ['9721', 'Food', 'блюд', '356', '360', 'neutral']
# ['9721', 'Food', 'еде', '383', '386', 'neutral']
# ['9721', 'Food', 'попробовать', '401', '412', 'neutral']
# ['9721', 'Food', 'меню', '423', '427', 'neutral']
# ['9721', 'Whole', 'ресторане', '29', '38', 'neutral']
# ['9721', 'Food', 'блюда', '626', '631', 'neutral']
# ['9721', 'Whole', 'ресторане', '29', '38', 'neutral']
# ['9721', 'Price', 'ценам', '747', '752', 'neutral']
# ['9721', 'Food', 'попробовать', '401', '412', 'neutral']
# ['9721', 'Food', 'коктейли', '848', '856', 'neutral']
# ['9721', 'Food', 'приготовленные', '858', '872', 'neutral']
# ['28083', 'Whole', 'ресторан', '12', '20', 'neutral']
# ['28083', 'Whole', 'паулайнере', '174', '184', 'positive']
# ['28083', 'Service', 'обслуживание', '228', '240', 'positive']
# ['28083', 'Food', 'кухня', '251', '256', 'positive']
# ['28083', 'Food', 'пиво', '262', '266', 'negative']
# ['28083', 'Service', 'заказывали', '410', '420', 'negative']
# ['28083', 'Service', 'персонал', '437', '445', 'neutral']
# ['28083', 'Service', 'обслуживала', '492', '503', 'positive']
# ['28083', 'Service', 'девушка', '515', '522', 'positive']
# ['28083', 'Service', 'девушка', '515', '522', 'positive']
# ['28083', 'Food', 'горячее', '832', '839', 'neutral']
# ['30744', 'Food', 'пивом', '150', '155', 'neutral']
# ['30744', 'Food', 'Гриль', '177', '182', 'neutral']
# ['30744', 'Food', 'пиво', '199', '203', 'neutral']
# ['30744', 'Food', 'вина', '226', '230', 'neutral']
# ['30744', 'Food', 'пива', '257', '261', 'neutral']
# ['30744', 'Service', 'сервиса', '311', '318', 'neutral']
# ['30744', 'Food', 'кухни', '323', '328', 'neutral']
# ['30744', 'Interior', 'атмосферы', '334', '343', 'neutral']
# ['30744', 'Interior', 'музыка', '381', '387', 'positive']
# ['3976', 'Whole', 'ресторане', '71', '80', 'neutral']
# ['3976', 'Whole', 'ресторанах', '198', '208', 'neutral']
# ['3976', 'Whole', 'ресторане', '71', '80', 'neutral']
# ['3976', 'Service', 'администратор', '322', '335', 'neutral']
# ['3976', 'Whole', 'ресторан', '413', '421', 'neutral']
# ['3976', 'Whole', 'ресторане', '71', '80', 'neutral']
# ['3976', 'Food', 'Меню', '564', '568', 'positive']
# ['3976', 'Service', 'Обслуживание', '688', '700', 'neutral']
# ['3976', 'Service', 'официанты', '739', '748', 'neutral']
# ['3976', 'Interior', 'Интерьер', '854', '862', 'positive']
# ['3976', 'Interior', 'диваны', '880', '886', 'positive']
# ['3976', 'Interior', 'ведущий', '933', '940', 'positive']
# ['3976', 'Whole', 'ресторан', '413', '421', 'positive']
# ['3976', 'Food', 'кухня', '1038', '1043', 'positive']
# ['3976', 'Whole', 'Руководству', '1053', '1064', 'positive']
# ['3976', 'Service', 'персоналу', '1067', '1076', 'positive']
# ['27040', 'Service', 'обслуживание', '124', '136', 'positive']
# ['27040', 'Service', 'официант', '159', '167', 'positive']
# ['27040', 'Service', 'кальян', '259', '265', 'positive']
# ['27040', 'Food', 'фрукты', '315', '321', 'positive']
# ['33591', 'Whole', 'кафе', '9', '13', 'positive']
# ['33591', 'Food', 'еда', '107', '110', 'positive']
# ['33591', 'Food', 'блюда', '120', '125', 'positive']
# ['33591', 'Interior', 'обстановка', '127', '137', 'positive']
# ['33591', 'Service', 'администратор', '148', '161', 'positive']
# ['33591', 'Whole', 'кафе', '9', '13', 'neutral']
# ['33591', 'Price', 'цены', '210', '214', 'neutral']
# ['33591', 'Whole', 'место', '764', '769', 'neutral']
# ['33591', 'Food', 'лосось', '375', '381', 'positive']
# ['33591', 'Food', 'кусок', '383', '388', 'positive']
# ['33591', 'Food', 'еды', '437', '440', 'neutral']
# ['33591', 'Interior', 'антураж', '562', '569', 'neutral']
# ['33591', 'Interior', 'караоке', '700', '707', 'positive']
# ['33591', 'Food', 'кальян', '730', '736', 'neutral']
# ['33591', 'Whole', 'место', '764', '769', 'positive']
# ['33591', 'Interior', 'обстановке', '889', '899', 'positive']
# ['28258', 'Food', 'поужинать', '16', '25', 'neutral']
# ['28258', 'Service', 'встретил', '69', '77', 'neutral']
# ['28258', 'Service', 'парковщик', '78', '87', 'neutral']
# ['28258', 'Service', 'помог', '89', '94', 'neutral']
# ['28258', 'Service', 'поприветствовал', '144', '159', 'neutral']
# ['28258', 'Interior', 'Интерьер', '161', '169', 'positive']
# ['28258', 'Interior', 'дизайн', '208', '214', 'positive']
# ['28258', 'Service', 'обслуживала', '270', '281', 'positive']
# ['28258', 'Service', 'девушка', '291', '298', 'positive']
# ['28258', 'Service', 'помогла', '370', '377', 'neutral']
# ['28258', 'Food', 'пасты', '538', '543', 'neutral']
# ['28258', 'Food', 'вареники', '62', '[[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...],  ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15420/3149272429.py in <module>
#       8         line = line.rstrip('\r\n').split('\t')
#       9         print(line)
# ---> 10         start, end = int(line[3]), int(line[4])
#      11         category = line[1]
#      12         doc_gold_aspect_cats = gold_aspect_cats[line[0]]
#
# ValueError: invalid literal for int() with base 10: '[[...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [...], [.

# %%
gold_size = sum([len(gold_aspect_cats[x]["cats"]) for x in gold_aspect_cats])

# %%
print(f"""
Full match precision: {full_match / total}
Full match recall: {full_match / gold_size}
Partial match ratio in pred: {(full_match + partial_match)  / total}
Full category accuracy: {full_cat_match / total}
Partial category accuracy: {(full_cat_match + partial_cat_match) / total}
""")
# Out:
# Full match precision: 0.9577039274924471
# Full match recall: 0.26638655462184874
# Partial match ratio in pred: 0.9939577039274925
# Full category accuracy: 0.9577039274924471
# Partial category accuracy: 0.9939577039274925

# %% [markdown]
# Было:
#
# Full match precision: 0.48
# Full match recall: 0.7159663865546219
# Partial match ratio in pred: 0.6197183098591549
# Full category accuracy: 0.46422535211267607
# Partial category accuracy: 0.6033802816901408

# %% [markdown]
# # Оценка 2: accuracy по тональности упоминаний

# %%
def sentiment_accuracy(matches):
    matched_sentiment = 0.
    for pair in matches:
        *_, gold_s = pair[0]
        *_, pred_s = pair[1]
        if gold_s == pred_s:
            matched_sentiment += 1
    print(f"Mention sentiment accuracy: {matched_sentiment / len(matches)}")

# %% [markdown]
# Accuracy по полностью совпавшим упоминаниям:

# %%
sentiment_accuracy(fully_matched_pairs)
# Out:
# Mention sentiment accuracy: 0.5205047318611987

# %% [markdown]
# Accuracy по частично совпавшим упоминаниям:

# %%
sentiment_accuracy(partially_matched_pairs)
# Out:
# Mention sentiment accuracy: 0.6666666666666666

# %% [markdown]
# # Оценка 3: accuracy по тональности категории

# %%
gold_test_cats_path = "dev_cats.txt"
pred_test_cats_path = "dev_pred_cats_formatted_last.txt"

# %%
with open(gold_test_cats_path) as gc, open(pred_test_cats_path) as pc:
    gold_labels = set(gc.readlines())
    pred_labels = set(pc.readlines())
    print(
        "Overall sentiment accuracy:",
        len(gold_labels & pred_labels) / len(gold_labels)
    )
    #print(pred_labels.difference(gold_labels))
# Out:
# Overall sentiment accuracy: 0.4619718309859155
